# %% [markdown]
# Generate pages

# %% [markdown]
# ## Read the XBRL-instance

# %%
from arelle import ViewFileDTS, ViewFileFactTable, ViewFileFactList, ModelManager, FileSource, ViewFileRelationshipSet
from arelle import Cntlr, ModelXbrl, ModelDocument, ViewFileFormulae
from arelle import ModelFormulaObject, RenderingEvaluator, XbrlConst
from arelle.ModelDtsObject import ModelRelationship
import arelle

# %%
import src
import pandas as pd
import re
import os
from os import listdir, walk, makedirs
from os.path import isfile, join, exists, basename
from io import StringIO

# %%
# make sure you have a 'arelle' directory in the data_path! (This is where the taxonomy is stored)
XBRL_DATA_PATH    = 'C:\\Users\\wjwil\\20_local_data\\xbrl\\' 
#DATA_PATH    = 'H:\\20_local_data\\xbrl\\' 
XBRL_RESULTS_PATH = 'C:\\Users\\wjwil\\50_results\\xbrl\\'
LANGUAGE     = "en-GB"
# set the location of taxonomy
os.environ['XDG_CONFIG_HOME'] = XBRL_DATA_PATH

# %%
DOCS_PATH ="..\\docs\\"
DATA_PATH ="..\\data\\"
RULES_PATH = "..\\Solvency2-rules\\"

# %%
# Now we make a modelmanager
controller = Cntlr.Cntlr()
controller.webCache.workOffline = True

modelmanager = ModelManager.initialize(controller)
modelmanager.defaultLang = LANGUAGE
modelmanager.formulaOptions = ModelFormulaObject.FormulaOptions()
modelmanager.loadCustomTransforms()

# %%
template_dict = {}
datapoint_dict = {}
instances = [file for file in listdir(XBRL_DATA_PATH) if file.endswith(".xbrl")]
# And we read the XBRL instance
for file in instances:
    print(file)
    xbrl_instance = ModelXbrl.load(modelmanager, join(XBRL_DATA_PATH, file))
    linkRoleUris = xbrl_instance.relationshipSet("Table-rendering").linkRoleUris
    for role_uri in linkRoleUris:
        definition = basename(role_uri)
        tblAxisRelSet = xbrl_instance.relationshipSet(XbrlConst.euTableAxis, role_uri)
        if len(tblAxisRelSet.modelRelationships)==0:
            tblAxisRelSet = xbrl_instance.relationshipSet((XbrlConst.tableBreakdown, XbrlConst.tableBreakdownMMDD, XbrlConst.tableBreakdown201305, XbrlConst.tableBreakdown201301, XbrlConst.tableAxis2011), role_uri)
        for rootconcept in tblAxisRelSet.rootConcepts:
            # rootconcept is a modelTable-object
            template_dict[rootconcept.definitionLabelsView[2][1]] = rootconcept.definitionLabelsView[3][1]
    tables = list(xbrl_instance.relationshipSet("Table-rendering").linkRoleUris)
    RenderingEvaluator.init(xbrl_instance)
    datapoint_dict.update(src.rc2label.rc2label_dict(xbrl_instance))
# Out:
# aeb_240_instance.xbrl
# Closed definition node s2md_c6998 does not contribute at least one structural node
# Closed definition node s2md_c7045 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c4423 does not contribute at least one structural node
# Closed definition node s2md_c304 does not contribute at least one structural node
# Closed definition node s2md_c5332 does not contribute at least one structural node
# Closed definition node s2md_c548 does not contribute at least one structural node
# Closed definition node s2md_c2643 does not contribute at least one structural node
# Closed definition node s2md_c2647 does not contribute at least one structural node
# Closed definition node s2md_c2659 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# Closed definition node s2md_c574 does not contribute at least one structural node
# Closed definition node s2md_c416 does not contribute at least one structural node
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c5664 does not contribute at least one structural node
# Closed definition node s2md_c6862 does not contribute at least one structural node
# Closed definition node s2md_c6087 does not contribute at least one structural node
# Closed definition node s2md_c4223 does not contribute at least one structural node
# Closed definition node s2md_c6903 does not contribute at least one structural node
# Closed definition node s2md_c5484 does not contribute at least one structural node
# Closed definition node s2md_c5535 does not contribute at least one structural node
# Closed definition node s2md_c2735 does not contribute at least one structural node
# Closed definition node s2md_c2739 does not contribute at least one structural node
# Closed definition node s2md_c2746 does not contribute at least one structural node
# aes_240_instance.xbrl
# Closed definition node s2md_c6998 does not contribute at least one structural node
# Closed definition node s2md_c7045 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c4527 does not contribute at least one structural node
# Closed definition node s2md_c4530 does not contribute at least one structural node
# Closed definition node s2md_c499 does not contribute at least one structural node
# Closed definition node s2md_c5332 does not contribute at least one structural node
# Closed definition node s2md_c2643 does not contribute at least one structural node
# Closed definition node s2md_c2647 does not contribute at least one structural node
# Closed definition node s2md_c2659 does not contribute at least one structural node
# Closed definition node s2md_c266 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c4300 does not contribute at least one structural node
# Closed definition node s2md_c6862 does not contribute at least one structural node
# Closed definition node s2md_c5664 does not contribute at least one structural node
# Closed definition node s2md_c6087 does not contribute at least one structural node
# Closed definition node s2md_c325 does not contribute at least one structural node
# Closed definition node s2md_c4223 does not contribute at least one structural node
# Closed definition node s2md_c6903 does not contribute at least one structural node
# Closed definition node s2md_c5484 does not contribute at least one structural node
# Closed definition node s2md_c5535 does not contribute at least one structural node
# Closed definition node s2md_c2735 does not contribute at least one structural node
# Closed definition node s2md_c2739 does not contribute at least one structural node
# Closed definition node s2md_c2746 does not contribute at least one structural node
# aspect-cover-filter.xsd: file error: [Errno 2] No such file or directory: 'C:\\Users\\wjwil\\20_local_data\\xbrl\\arelle\\cache\\http\\xbrl.org\\2010\\aspect-cover-filter.xsd'
# afb_240_instance.xbrl
# Closed definition node s2md_c548 does not contribute at least one structural node
# Closed definition node s2md_c9588 does not contribute at least one structural node
# Closed definition node s2md_c574 does not contribute at least one structural node
# Closed definition node s2md_c9593 does not contribute at least one structural node
# Closed definition node s2md_c254 does not contribute at least one structural node
# aspect-cover-filter.xsd: file error: [Errno 2] No such file or directory: 'C:\\Users\\wjwil\\20_local_data\\xbrl\\arelle\\cache\\http\\xbrl.org\\2010\\aspect-cover-filter.xsd'
# afg_240_instance.xbrl
# Closed definition node s2md_c9588 does not contribute at least one structural node
# Closed definition node s2md_c523 does not contribute at least one structural node
# Closed definition node s2md_c9593 does not contribute at least one structural node
# Closed definition node s2md_c238 does not contribute at least one structural node
# aspect-cover-filter.xsd: file error: [Errno 2] No such file or directory: 'C:\\Users\\wjwil\\20_local_data\\xbrl\\arelle\\cache\\http\\xbrl.org\\2010\\aspect-cover-filter.xsd'
# afs_240_instance.xbrl
# Closed definition node s2md_c9588 does not contribute at least one structural node
# Closed definition node s2md_c9593 does not contribute at least one structural node
# Closed definition node s2md_c226 does not contribute at least one structural node
# Closed definition node s2md_c499 does not contribute at least one structural node
# apg_240_instance.xbrl
# Closed definition node s2md_c5635 does not contribute at least one structural node
# Closed definition node s2md_c4511 does not contribute at least one structural node
# Closed definition node s2md_c5450 does not contribute at least one structural node
# aps_240_instance.xbrl
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c2703 does not contribute at least one structural node
# Closed definition node s2md_c2707 does not contribute at least one structural node
# Closed definition node s2md_c2714 does not contribute at least one structural node
# Closed definition node s2md_c5607 does not contribute at least one structural node
# Closed definition node s2md_c4300 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c5418 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# arb_240_instance.xbrl
# Closed definition node s2md_c6998 does not contribute at least one structural node
# Closed definition node s2md_c7045 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c4423 does not contribute at least one structural node
# Closed definition node s2md_c304 does not contribute at least one structural node
# Closed definition node s2md_c5332 does not contribute at least one structural node
# Closed definition node s2md_c548 does not contribute at least one structural node
# Closed definition node s2md_c2643 does not contribute at least one structural node
# Closed definition node s2md_c2647 does not contribute at least one structural node
# Closed definition node s2md_c2659 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# Closed definition node s2md_c574 does not contribute at least one structural node
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c147 does not contribute at least one structural node
# Closed definition node s2md_c6862 does not contribute at least one structural node
# Closed definition node s2md_c5664 does not contribute at least one structural node
# Closed definition node s2md_c6087 does not contribute at least one structural node
# Closed definition node s2md_c4223 does not contribute at least one structural node
# Closed definition node s2md_c6903 does not contribute at least one structural node
# Closed definition node s2md_c5484 does not contribute at least one structural node
# Closed definition node s2md_c5535 does not contribute at least one structural node
# Closed definition node s2md_c2735 does not contribute at least one structural node
# Closed definition node s2md_c2739 does not contribute at least one structural node
# Closed definition node s2md_c2746 does not contribute at least one structural node
# arg_240_instance.xbrl
# Closed definition node s2md_c6998 does not contribute at least one structural node
# Closed definition node s2md_c7045 does not contribute at least one structural node
# Closed definition node s2md_c523 does not contribute at least one structural node
# Closed definition node s2md_c6929 does not contribute at least one structural node
# Closed definition node s2md_c6970 does not contribute at least one structural node
# Closed definition node s2md_c4582 does not contribute at least one structural node
# Closed definition node s2md_c4585 does not contribute at least one structural node
# Closed definition node s2md_c5939 does not contribute at least one structural node
# Closed definition node s2md_c5383 does not contribute at least one structural node
# Closed definition node s2md_c5581 does not contribute at least one structural node
# Closed definition node s2md_c5664 does not contribute at least one structural node
# Closed definition node s2md_c287 does not contribute at least one structural node
# Closed definition node s2md_c88 does not contribute at least one structural node
# Closed definition node s2md_c6120 does not contribute at least one structural node
# Closed definition node s2md_c5484 does not contribute at least one structural node
# Closed definition node s2md_c4383 does not contribute at least one structural node
# ars_240_instance.xbrl
# Closed definition node s2md_c6998 does not contribute at least one structural node
# Closed definition node s2md_c7045 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c4527 does not contribute at least one structural node
# Closed definition node s2md_c4530 does not contribute at least one structural node
# Closed definition node s2md_c499 does not contribute at least one structural node
# Closed definition node s2md_c5332 does not contribute at least one structural node
# Closed definition node s2md_c2643 does not contribute at least one structural node
# Closed definition node s2md_c2647 does not contribute at least one structural node
# Closed definition node s2md_c2659 does not contribute at least one structural node
# Closed definition node s2md_c1 does not contribute at least one structural node
# Closed definition node s2md_c266 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c4300 does not contribute at least one structural node
# Closed definition node s2md_c5664 does not contribute at least one structural node
# Closed definition node s2md_c6862 does not contribute at least one structural node
# Closed definition node s2md_c6087 does not contribute at least one structural node
# Closed definition node s2md_c4223 does not contribute at least one structural node
# Closed definition node s2md_c6903 does not contribute at least one structural node
# Closed definition node s2md_c5484 does not contribute at least one structural node
# Closed definition node s2md_c5535 does not contribute at least one structural node
# Closed definition node s2md_c2735 does not contribute at least one structural node
# Closed definition node s2md_c2739 does not contribute at least one structural node
# Closed definition node s2md_c2746 does not contribute at least one structural node
# qeb_240_instance.xbrl
# Closed definition node s2md_c4423 does not contribute at least one structural node
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c2703 does not contribute at least one structural node
# Closed definition node s2md_c2707 does not contribute at least one structural node
# Closed definition node s2md_c2714 does not contribute at least one structural node
# Closed definition node s2md_c548 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c484 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# Closed definition node s2md_c574 does not contribute at least one structural node
# qes_240_instance.xbrl
# Closed definition node s2md_c401 does not contribute at least one structural node
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c499 does not contribute at least one structural node
# Closed definition node s2md_c2703 does not contribute at least one structural node
# Closed definition node s2md_c2707 does not contribute at least one structural node
# Closed definition node s2md_c2714 does not contribute at least one structural node
# Closed definition node s2md_c4300 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# aspect-cover-filter.xsd: file error: [Errno 2] No such file or directory: 'C:\\Users\\wjwil\\20_local_data\\xbrl\\arelle\\cache\\http\\xbrl.org\\2010\\aspect-cover-filter.xsd'
# qfb_240_instance.xbrl
# Closed definition node s2md_c548 does not contribute at least one structural node
# Closed definition node s2md_c574 does not contribute at least one structural node
# Closed definition node s2md_c9591 does not contribute at least one structural node
# Closed definition node s2md_c260 does not contribute at least one structural node
# Closed definition node s2md_c9595 does not contribute at least one structural node
# qfg_240_instance.xbrl
# Closed definition node s2md_c244 does not contribute at least one structural node
# Closed definition node s2md_c9591 does not contribute at least one structural node
# Closed definition node s2md_c523 does not contribute at least one structural node
# Closed definition node s2md_c9595 does not contribute at least one structural node
# aspect-cover-filter.xsd: file error: [Errno 2] No such file or directory: 'C:\\Users\\wjwil\\20_local_data\\xbrl\\arelle\\cache\\http\\xbrl.org\\2010\\aspect-cover-filter.xsd'
# qfs_240_instance.xbrl
# Closed definition node s2md_c232 does not contribute at least one structural node
# Closed definition node s2md_c9591 does not contribute at least one structural node
# Closed definition node s2md_c9595 does not contribute at least one structural node
# Closed definition node s2md_c499 does not contribute at least one structural node
# qrb_240_instance.xbrl
# Closed definition node s2md_c4423 does not contribute at least one structural node
# Closed definition node s2md_c212 does not contribute at least one structural node
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c2703 does not contribute at least one structural node
# Closed definition node s2md_c2707 does not contribute at least one structural node
# Closed definition node s2md_c2714 does not contribute at least one structural node
# Closed definition node s2md_c548 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c574 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# qrg_240_instance.xbrl
# Closed definition node s2md_c137 does not contribute at least one structural node
# Closed definition node s2md_c523 does not contribute at least one structural node
# Closed definition node s2md_c4383 does not contribute at least one structural node
# qrs_240_instance.xbrl
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c499 does not contribute at least one structural node
# Closed definition node s2md_c2703 does not contribute at least one structural node
# Closed definition node s2md_c2707 does not contribute at least one structural node
# Closed definition node s2md_c2714 does not contribute at least one structural node
# Closed definition node s2md_c74 does not contribute at least one structural node
# Closed definition node s2md_c4300 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# spv_240_instance.xbrl
# aspect-cover-filter.xsd: file error: [Errno 2] No such file or directory: 'C:\\Users\\wjwil\\20_local_data\\xbrl\\arelle\\cache\\http\\xbrl.org\\2010\\aspect-cover-filter.xsd'
# Closed definition node s2md_c9626 does not contribute at least one structural node
# Closed definition node s2md_c9619 does not contribute at least one structural node
# template_instance.xbrl
# module URL: file error: [Errno 2] No such file or directory: 'C:\\Users\\wjwil\\20_local_data\\xbrl\\module URL'
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x7', 's2c_CU:x6', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x161', 's2c_LB:x160',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:GB', 's2c_GA:SE', 's2..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CA:x0', 's2c_CA:x1'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_AM:x88', 's2c_AM:x4'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_CU:x0', 's2c_CU:EUR', 's..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_LB:x67', 's2c_LB:x106', ..., pattern mismatch
# ...
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_GA:x114', 's2c_GA:x113',..., pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Element xbrldi:explicitMember type QName value error: ['s2c_PU:x54', 's2c_PU:x60'], pattern mismatch
# Instance facts missing schema concept definition: s2md_met:bi7, s2md_met:di1028, s2md_met:di1029, s2md_met:di1030, s2md_met:di1031, s2md_met:di1032, s2md_met:di1033, s2md_met:di1034, s2md_met:di1036, s2md_met:di1037, s2md_met:di1039, s2md_met:di1040, s2md_met:di1041, s2md_met:di1043, s2md_met:di1044, s2md_met:di1045, s2md_met:di1047, s2md_met:di1048, s2md_met:di1839, s2md_met:di1840, s2md_met:di1864, s2md_met:di2202, s2md_met:di2502, s2md_met:di2509, s2md_met:ei1001, s2md_met:ei1003, s2md_met:ei1007, s2md_met:ei1008, s2md_met:ei1018, s2md_met:ei1019, s2md_met:ei1022, s2md_met:ei1023, s2md_met:ei1024, s2md_met:ei1026, s2md_met:ei1055, s2md_met:ei1061, s2md_met:ei1062, s2md_met:ei1070, s2md_met:ei1072, s2md_met:ei1074, s2md_met:ei1075, s2md_met:ei1280, s2md_met:ei1281, s2md_met:ei1282, s2md_met:ei1396, s2md_met:ei1397, s2md_met:ei1399, s2md_met:ei1400, s2md_met:ei1507, s2md_met:ei1508, s2md_met:ei1513, s2md_met:ei1518, s2md_met:ei1549, s2md_met:ei1592, s2md_met:ei1631, s2md_met:ei1632, s2md_met:ei1633, s2md_met:ei1634, s2md_met:ei1642, s2md_met:ei1643, s2md_met:ei1655, s2md_met:ei1658, s2md_met:ei1668, s2md_met:ei1669, s2md_met:ei1670, s2md_met:ei1671, s2md_met:ei1672, s2md_met:ei1673, s2md_met:ei1674, s2md_met:ei1676, s2md_met:ei1677, s2md_met:ei1678, s2md_met:ei1679, s2md_met:ei1680, s2md_met:ei1681, s2md_met:ei1682, s2md_met:ei1683, s2md_met:ei1684, s2md_met:ei1685, s2md_met:ei1687, s2md_met:ei1688, s2md_met:ei1689, s2md_met:ei1691, s2md_met:ei1692, s2md_met:ei1693, s2md_met:ei1697, s2md_met:ei1698, s2md_met:ei1701, s2md_met:ei1702, s2md_met:ei1703, s2md_met:ei1704, s2md_met:ei1705, s2md_met:ei1706, s2md_met:ei1707, s2md_met:ei1708, s2md_met:ei1709, s2md_met:ei1710, s2md_met:ei1711, s2md_met:ei1712, s2md_met:ei1713, s2md_met:ei1715, s2md_met:ei1717, s2md_met:ei1719, s2md_met:ei1720, s2md_met:ei1721, s2md_met:ei1722, s2md_met:ei1723, s2md_met:ei1725, s2md_met:ei1726, s2md_met:ei1731, s2md_met:ei1734, s2md_met:ei1735, s2md_met:ei1736, s2md_met:ei1737, s2md_met:ei1738, s2md_met:ei1739, s2md_met:ei1742, s2md_met:ei1743, s2md_met:ei1754, s2md_met:ei1755, s2md_met:ei1756, s2md_met:ei1757, s2md_met:ei1758, s2md_met:ei1759, s2md_met:ei1760, s2md_met:ei1761, s2md_met:ei1762, s2md_met:ei1763, s2md_met:ei1764, s2md_met:ei1765, s2md_met:ei1766, s2md_met:ei1767, s2md_met:ei1768, s2md_met:ei1769, s2md_met:ei1770, s2md_met:ei1771, s2md_met:ei1772, s2md_met:ei1773, s2md_met:ei1774, s2md_met:ei1775, s2md_met:ei1776, s2md_met:ei1777, s2md_met:ei1778, s2md_met:ei1786, s2md_met:ei1787, s2md_met:ei1793, s2md_met:ei1795, s2md_met:ei1811, s2md_met:ei1814, s2md_met:ei1817, s2md_met:ei1818, s2md_met:ei1822, s2md_met:ei1834, s2md_met:ei1836, s2md_met:ei1838, s2md_met:ei1844, s2md_met:ei1845, s2md_met:ei1846, s2md_met:ei1847, s2md_met:ei1848, s2md_met:ei1849, s2md_met:ei1851, s2md_met:ei1852, s2md_met:ei1857, s2md_met:ei1859, s2md_met:ei1860, s2md_met:ei1863, s2md_met:ei1865, s2md_met:ei1866, s2md_met:ei1867, s2md_met:ei1868, s2md_met:ei1870, s2md_met:ei1871, s2md_met:ei1872, s2md_met:ei1873, s2md_met:ei1885, s2md_met:ei1886, s2md_met:ei1887, s2md_met:ei1888, s2md_met:ei1889, s2md_met:ei1890, s2md_met:ei1892, s2md_met:ei1894, s2md_met:ei1895, s2md_met:ei1896, s2md_met:ei1902, s2md_met:ei1904, s2md_met:ei1905, s2md_met:ei1930, s2md_met:ei1931, s2md_met:ei1960, s2md_met:ei1961, s2md_met:ei2104, s2md_met:ei2130, s2md_met:ei2138, s2md_met:ei2139, s2md_met:ei2140, s2md_met:ei2157, s2md_met:ei2158, s2md_met:ei2167, s2md_met:ei2168, s2md_met:ei2171, s2md_met:ei2172, s2md_met:ei2173, s2md_met:ei2174, s2md_met:ei2177, s2md_met:ei2178, s2md_met:ei2181, s2md_met:ei2203, s2md_met:ei2210, s2md_met:ei2211, s2md_met:ei2212, s2md_met:ei2213, s2md_met:ei2214, s2md_met:ei2215, s2md_met:ei2218, s2md_met:ei2219, s2md_met:ei2222, s2md_met:ei2291, s2md_met:ei2292, s2md_met:ei2293, s2md_met:ei2294, s2md_met:ei2296, s2md_met:ei2298, s2md_met:ei2299, s2md_met:ei2300, s2md_met:ei2340, s2md_met:ei2341, s2md_met:ei2342, s2md_met:ei2343, s2md_met:ei2344, s2md_met:ei2345, s2md_met: ...
# tep_240_instance.xbrl
# Closed definition node s2md_c4511 does not contribute at least one structural node
# Closed definition node s2md_c9619 does not contribute at least one structural node
# Closed definition node s2md_c7045 does not contribute at least one structural node
# Closed definition node s2md_c5607 does not contribute at least one structural node
# Closed definition node s2md_c523 does not contribute at least one structural node
# Closed definition node s2md_c4527 does not contribute at least one structural node
# Closed definition node s2md_c4530 does not contribute at least one structural node
# Closed definition node s2md_c304 does not contribute at least one structural node
# Closed definition node s2md_c2643 does not contribute at least one structural node
# Closed definition node s2md_c2647 does not contribute at least one structural node
# Closed definition node s2md_c2659 does not contribute at least one structural node
# Closed definition node s2md_c232 does not contribute at least one structural node
# Closed definition node s2md_c6862 does not contribute at least one structural node
# Closed definition node s2md_c137 does not contribute at least one structural node
# Closed definition node s2md_c9591 does not contribute at least one structural node
# Closed definition node s2md_c5450 does not contribute at least one structural node
# Closed definition node s2md_c5535 does not contribute at least one structural node
# Closed definition node s2md_c6998 does not contribute at least one structural node
# Closed definition node s2md_c484 does not contribute at least one structural node
# Closed definition node s2md_c9626 does not contribute at least one structural node
# Closed definition node s2md_c499 does not contribute at least one structural node
# Closed definition node s2md_c266 does not contribute at least one structural node
# Closed definition node s2md_c8912 does not contribute at least one structural node
# Closed definition node s2md_c2703 does not contribute at least one structural node
# Closed definition node s2md_c2707 does not contribute at least one structural node
# Closed definition node s2md_c2714 does not contribute at least one structural node
# Closed definition node s2md_c254 does not contribute at least one structural node
# Closed definition node s2md_c287 does not contribute at least one structural node
# Closed definition node s2md_c5418 does not contribute at least one structural node
# Closed definition node s2md_c226 does not contribute at least one structural node
# Closed definition node s2md_c244 does not contribute at least one structural node
# Closed definition node s2md_c6120 does not contribute at least one structural node
# Closed definition node s2md_c5484 does not contribute at least one structural node
# Closed definition node s2md_c238 does not contribute at least one structural node
# Closed definition node s2md_c4383 does not contribute at least one structural node
# Closed definition node s2md_c4423 does not contribute at least one structural node
# Closed definition node s2md_c5332 does not contribute at least one structural node
# Closed definition node s2md_c1 does not contribute at least one structural node
# Closed definition node s2md_c5939 does not contribute at least one structural node
# Closed definition node s2md_c401 does not contribute at least one structural node
# Closed definition node s2md_c212 does not contribute at least one structural node
# Closed definition node s2md_c9593 does not contribute at least one structural node
# Closed definition node s2md_c147 does not contribute at least one structural node
# Closed definition node s2md_c4300 does not contribute at least one structural node
# Closed definition node s2md_c6087 does not contribute at least one structural node
# Closed definition node s2md_c325 does not contribute at least one structural node
# Closed definition node s2md_c4223 does not contribute at least one structural node
# Closed definition node s2md_c6903 does not contribute at least one structural node
# Closed definition node s2md_c74 does not contribute at least one structural node
# Closed definition node s2md_c5635 does not contribute at least one structural node
# Closed definition node s2md_c8968 does not contribute at least one structural node
# Closed definition node s2md_c6929 does not contribute at least one structural node
# Closed definition node s2md_c548 does not contribute at least one structural node
# Closed definition node s2md_c6970 does not contribute at least one structural node
# Closed definition node s2md_c4582 does not contribute at least one structural node
# Closed definition node s2md_c4585 does not contribute at least one structural node
# Closed definition node s2md_c9595 does not contribute at least one structural node
# Closed definition node s2md_c8902 does not contribute at least one structural node
# Closed definition node s2md_c574 does not contribute at least one structural node
# Closed definition node s2md_c260 does not contribute at least one structural node
# Closed definition node s2md_c416 does not contribute at least one structural node
# Closed definition node s2md_c5383 does not contribute at least one structural node
# Closed definition node s2md_c5581 does not contribute at least one structural node
# Closed definition node s2md_c5664 does not contribute at least one structural node
# Closed definition node s2md_c88 does not contribute at least one structural node
# Closed definition node s2md_c9588 does not contribute at least one structural node
# Closed definition node s2md_c2735 does not contribute at least one structural node
# Closed definition node s2md_c2739 does not contribute at least one structural node
# Closed definition node s2md_c2746 does not contribute at least one structural node

# %%
f = open(join(DATA_PATH, "datapoints.txt"),"w")
f.write(str(datapoint_dict))
f.close()
f = open(join(DATA_PATH, "templates.txt"),"w")
f.write(str(template_dict))
f.close()

# %% [markdown]
# ## Read DNB Validation rules

# %%
FILE_NAME = '2020-01-22 Set aanvullende controleregels Solvency II_tcm46-387021.xlsx'
DIR_NAME = "DNB Additional validation rules.2.4.0"

df_dnb = pd.read_excel(os.path.join(RULES_PATH, FILE_NAME), header = 1)
df_dnb = df_dnb.set_index('ControleRegelCode')
df_dnb = df_dnb.drop('S.01.03_110', axis = 0)
df_dnb.fillna("", inplace = True)

# %%
df = pd.DataFrame()
for row in df_dnb.index:
    expr = df_dnb.loc[row, 'Formule']
    label = ""
    rule_templates, rule_datapoints, rule_id, rule_ref = src.parse_formula(expr, syntax = "EVA2")
    rule_id = row
    rule_date = "2010-01-22"
    df = df.append(pd.DataFrame(data = [[rule_id, label, rule_templates, rule_datapoints, rule_ref, expr]]), ignore_index = True)
df.columns = ['Rule id', 'Rule label', 'Rule templates', 'Rule datapoints', 'Rule references', 'Rule expression']

# %%
len(datapoint_dict.keys())
# Out:
# 34746

# %%
for row in df.index:
    l = df.loc[row, 'Rule datapoints']
    for item in l:
        if not item in datapoint_dict.keys():
            print(item)
# Out:
# S.01.03.04.01,c0040
# S.01.03.04.01,c0040
# S.01.03.04.01,c0040
# S.01.03.04.01,c0040
# S.01.03.04.01,c0040
# S.01.03.01.02,c0110
# S.01.03.04.02,c0110
# S.06.03.01.01,c0010
# S.06.03.04.01,c0010
# S.07.01.01.01,c0040
# S.07.01.04.01,c0040
# S.07.01.01.01,c0040
# S.07.01.04.01,c0040
# S.07.01.01.01,c0040
# S.07.01.04.01,c0040
# S.07.01.01.01,c0040
# S.07.01.04.01,c0040
# S.07.01.01.01,c0040
# S.07.01.04.01,c0040
# S.07.01.01.01,c0040
# S.07.01.04.01,c0040
# S.07.01.01.01,c0040
# S.07.01.04.01,c0040
# S.10.01.04.01,C0180
# S.10.01.04.01,C0180
# S.10.01.04.01,C0180
# S.10.01.04.01,C0180
# S.10.01.04.01,C0180
# S.10.01.04.01,C0180
# S.10.01.04.01,C0120
# S.10.01.04.01,C0180
# S.15.01.04.01,c0020
# S.24.01.01.04,r0040
# S.25.02.01.01,rNNN,c0030
# S.25.02.04.01,rNNN,c0030
# S.26.01.01.01,r0420,c0020
# S.26.01.01.01,r0420,c0030
# S.26.01.01.01,r0420,c0040
# S.26.01.01.01,r0420,c0050
# S.26.01.04.01,r0420,c0020
# S.26.01.04.01,r0420,c0030
# S.26.01.04.01,r0420,c0040
# S.26.01.04.01,r0420,c0050
# S.26.01.01.01,r0420,c0020
# S.26.01.01.01,r0420,c0030
# S.26.01.01.01,r0420,c0040
# S.26.01.01.01,r0420,c0070
# S.26.01.04.01,r0420,c0020
# S.26.01.04.01,r0420,c0030
# S.26.01.04.01,r0420,c0040
# S.26.01.04.01,r0420,c0070
# S.27.01.01.02,R0600
# r0400,r0590
# S.27.01.04.02,R0600
# r0400,r0590
# c0080
# c0080
# S.27.01.01.02,R0600
# r0400,r0590
# S.27.01.04.02,R0600
# r0400,r0590
# c0170
# c0180
# c0190
# c0170
# c0180
# c0190
# c0170
# c0180
# c0190
# c0170
# c0180
# c0190
# r1410
# r1420
# r1430
# r1440
# r1450
# r1460
# r1470
# r1480
# r1490
# r1500
# r1510
# r1520
# r1530
# r1540
# r1550
# r1560
# r1570
# r1580
# r1590
# r1410
# r1420
# r1430
# r1440
# r1450
# r1460
# r1470
# r1480
# r1490
# r1500
# r1510
# r1520
# r1530
# r1540
# r1550
# r1560
# r1570
# r1580
# r1590
# S.27.01.01.20,r3500,c1220
# S.27.01.04.20,r3500,c1220
# S.27.01.01.21,r3900,c1340
# S.27.01.04.21,r3900,c1340
# S.30.01.01.02,c0200
# S.30.01.01.02,c0200
# S.30.01.01.02,c0200
# S.30.01.01.02,c0200
# S.30.01.01.02,c0200
# S.30.01.01.02,c0200
# S.30.01.01.02,c0200
# S.30.02.01.01,c0030
# S.30.02.01.01,c0030
# S.30.02.01.01,c0030
# S.30.02.01.02,c0170
# S.30.02.01.02,c0160
# S.30.02.01.02,c0160
# S.30.04.01.01,c0050
# S.30.04.01.01,c0050
# S.30.04.01.01,c0050
# S.36.01.01.01,c0010
# S.36.01.01.01,c0010
# S.36.01.01.01,c0010
# S.36.01.01.01,c0010
# S.36.01.01.01,c0010
# S.36.02.01.01,c0010
# S.36.02.01.01,c0010
# S.36.02.01.01,c0010
# S.36.02.01.01,c0010
# S.36.02.01.01,c0010
# S.36.02.01.01,c0010
# S.36.02.01.01,c0010
# S.36.02.01.01,c0010
# S.36.03.01.01,c0010
# S.36.03.01.01,c0010
# S.36.03.01.01,c0010
# S.36.03.01.01,c0010
# S.36.03.01.01,c0010
# S.36.03.01.01,c0010
# S.36.03.01.01,c0010
# S.36.03.01.01,c0010
# S.36.04.01.01,c0010
# S.36.04.01.01,c0010
# S.36.04.01.01,c0010
# S.36.04.01.01,c0010
# S.36.04.01.01,c0010
# S.37.01.04.01,c0020
# S.37.01.04.01,c0020
# S.37.01.04.01,c0020
# S.37.01.04.01,c0020
# S.37.01.04.01,c0020
# S.37.01.04.01,c0020

# %% [markdown]
# ## Generate subdirectories for DNB Validation rules

# %%
all_templates = []
for row in df.index:
    all_templates.extend(df.loc[row, "Rule templates"])
templates = list(pd.Series(data = all_templates).sort_values().unique())

for template in templates:
    if not exists(join(DOCS_PATH, DIR_NAME, template)):
        makedirs(join(DOCS_PATH, DIR_NAME, template))

# %%
src.write_rst(join(DOCS_PATH, DIR_NAME), df, template_dict, datapoint_dict)
